# %%
import sys
import os
import numpy as np

# Ensure the Reinforcemente_Learning directory is in the Python path
# (May not be necessary if running from the directory containing RL folder)
# sys.path.insert(0, os.path.abspath(os.path.dirname(__file__)))

try:
    import data_preparation
    import environment
    import model_training
    import evaluation
    import inference
except ImportError as e:
    print(f"Error importing modules: {e}")
    print("Please ensure all required files (data_preparation.py, environment.py, model_training.py, evaluation.py, inference.py) exist in the same directory.")
    sys.exit(1)

# --- Configuration ---
# Set these to True/False to control which phases run
RUN_DATA_PREPARATION = True
RUN_OFFLINE_TRAINING = True
RUN_EVALUATION = True
RUN_INTERACTIVE_PLAY = True # Renamed from RUN_INFERENCE_DEMO

# --- Parameters ---
# Assuming notebook runs from Reinforcemente_Learning directory
DATA_FILE = data_preparation.DATA_FILE # Get from data_preparation module
OFFLINE_BUFFER_FILE = 'offline_replay_buffer.npz'
FINAL_MODEL_FILE = 'offline_trained_model.pth' # Model trained offline is the final model

OFFLINE_EPOCHS = 5000  # Adjust as needed for training
BATCH_SIZE = model_training.BATCH_SIZE # Get from model_training module
EVALUATION_EPISODES = 1000
TARGET_LIFT_TIER = 1 # Example: Train/Evaluate primarily for this tier
SEED = 42 # For reproducibility

# --- Initialization ---
offline_buffer = None
agent = None
model_to_eval = None
inference_module = None

print("--- Configuration Loaded ---")
print(f"Current working directory: {os.getcwd()}")
# Out:
# --- Configuration Loaded ---
# Current working directory: c:\Users\gpnc_\OneDrive\Documentos\GitHub\Retail_Mardown_Game\Reinforcemente_Learning

# %% [markdown]
# ## Phase 1: Data Preparation

# %%
# === Phase 1: Data Preparation ===
if RUN_DATA_PREPARATION:
    print("\n--- Running Phase 1: Data Preparation ---")
    try:
        # Prepare data and get the buffer in memory
        # Assumes DATA_FILE is in the current directory
        offline_buffer = data_preparation.prepare_offline_data(data_path=DATA_FILE)

        # Save the buffer for potential reuse
        if offline_buffer:
            print(f"Saving offline buffer to {OFFLINE_BUFFER_FILE}...")
            # Save buffer in the same directory
            np.savez_compressed(OFFLINE_BUFFER_FILE, buffer=np.array(offline_buffer, dtype=object))
            print(f"Buffer with {len(offline_buffer)} experiences saved.")
        else:
            print("Warning: Offline buffer generation failed or returned empty.")
            raise Exception("Data preparation failed.") # Stop if no data

    except Exception as e:
        print(f"Error during Data Preparation: {e}")
        raise # Re-raise the exception to stop notebook execution
else:
    print("\n--- Skipping Phase 1: Data Preparation ---")
    # Try to load previously saved buffer if skipping prep and needed for training
    if RUN_OFFLINE_TRAINING or RUN_EVALUATION: # Load if needed for subsequent steps
        try:
            print(f"Loading offline buffer from {OFFLINE_BUFFER_FILE}...")
            loaded_data = np.load(OFFLINE_BUFFER_FILE, allow_pickle=True)
            offline_buffer = loaded_data['buffer'].tolist()
            print(f"Loaded {len(offline_buffer)} offline experiences.")
            if not offline_buffer:
                print("Error: Loaded offline buffer is empty.")
                raise Exception(f"{OFFLINE_BUFFER_FILE} is empty.")
        except FileNotFoundError:
            print(f"Error: {OFFLINE_BUFFER_FILE} not found. Cannot proceed without data preparation or existing buffer.")
            raise
        except Exception as e:
            print(f"Error loading offline buffer: {e}")
            raise
# Out:
# --- Running Phase 1: Data Preparation ---
# Loading raw data from raw_data.csv...
# Raw data loaded: 544000 rows.
# Columns found: ['combo', 'replication', 'week', 'price', 'sales', 'remain_invent']
# Parsing episodes and constructing RL tuples...
# Processed 1000/34000 episodes. Buffer size: 14915
# Processed 2000/34000 episodes. Buffer size: 29741
# Processed 3000/34000 episodes. Buffer size: 44436
# Processed 4000/34000 episodes. Buffer size: 59071
# Processed 5000/34000 episodes. Buffer size: 73704
# Processed 6000/34000 episodes. Buffer size: 87953
# Processed 7000/34000 episodes. Buffer size: 102586
# Processed 8000/34000 episodes. Buffer size: 116795
# Processed 9000/34000 episodes. Buffer size: 131148
# Processed 10000/34000 episodes. Buffer size: 145385
# Processed 11000/34000 episodes. Buffer size: 159110
# Processed 12000/34000 episodes. Buffer size: 173645
# Processed 13000/34000 episodes. Buffer size: 187692
# Processed 14000/34000 episodes. Buffer size: 201161
# Processed 15000/34000 episodes. Buffer size: 215091
# Processed 16000/34000 episodes. Buffer size: 229268
# Processed 17000/34000 episodes. Buffer size: 242878
# Processed 18000/34000 episodes. Buffer size: 256075
# Processed 19000/34000 episodes. Buffer size: 270106
# Processed 20000/34000 episodes. Buffer size: 284037
# Processed 21000/34000 episodes. Buffer size: 297436
# Processed 22000/34000 episodes. Buffer size: 310500
# Processed 23000/34000 episodes. Buffer size: 323364
# Processed 24000/34000 episodes. Buffer size: 337566
# Processed 25000/34000 episodes. Buffer size: 351173
# Processed 26000/34000 episodes. Buffer size: 364362
# Processed 27000/34000 episodes. Buffer size: 377254
# Processed 28000/34000 episodes. Buffer size: 389255
# Processed 29000/34000 episodes. Buffer size: 403591
# Processed 30000/34000 episodes. Buffer size: 417376
# Processed 31000/34000 episodes. Buffer size: 430590
# Processed 32000/34000 episodes. Buffer size: 443156
# Processed 33000/34000 episodes. Buffer size: 455570
# Processed 34000/34000 episodes. Buffer size: 467130
# Finished processing. Generated 467130 RL tuples.
# --- Offline Buffer Analysis (First 5 Tuples) ---
# Tuple 0: S=[ 1. 80.  0.  2.], A=0, R=6720.00, S'=[ 2. 76.  0.  2.], Done=False
# Tuple 1: S=[ 2. 76.  0.  2.], A=0, R=6600.00, S'=[ 3. 72.  0.  2.], Done=False
# Tuple 2: S=[ 3. 72.  0.  2.], A=0, R=3780.00, S'=[ 4. 69.  0.  2.], Done=False
# Tuple 3: S=[ 4. 69.  0.  2.], A=0, R=5160.00, S'=[ 5. 66.  0.  2.], Done=False
# Tuple 4: S=[ 5. 66.  0.  2.], A=0, R=9000.00, S'=[ 6. 60.  0.  2.], Done=False
# Total tuples: 467130
# Week distribution in states: [(1.0, 34000), (2.0, 34000), (3.0, 34000), (4.0, 34000), (5.0, 34000), (6.0, 33999), (7.0, 33991), (8.0, 33924), (9.0, 33689), (10.0, 33032), (11.0, 31659), (12.0, 29512), (13.0, 26366), (14.0, 22582), (15.0, 18376)]
# Action distribution: [(0, 386357), (1, 27996), (2, 27771), (3, 25006)]
# --- Validating Episode Rewards vs Week 16 Price (Total Revenue) ---
# Validation Summary: Passed=19765, Failed=14235, No W16 data=0
# Sample Mismatched Episodes (Calculated Sum vs. W16 'price' as Total Revenue):
#   FAIL: Combo 0, Rep 0 | Summed R: 102570.00, W16 Revenue: 105060.00, Diff: 2490.00
#   FAIL: Combo 0, Rep 1 | Summed R: 113000.00, W16 Revenue: 114000.00, Diff: 1000.00
#   FAIL: Combo 0, Rep 2 | Summed R: 74010.00, W16 Revenue: 80580.00, Diff: 6570.00
#   FAIL: Combo 0, Rep 3 | Summed R: 87450.00, W16 Revenue: 92100.00, Diff: 4650.00
#   FAIL: Combo 0, Rep 4 | Summed R: 53990.00, W16 Revenue: 63420.00, Diff: 9430.00
# Reward sum validation against Week 16 'price' (as total revenue) had some mismatches.
# Saving offline buffer to offline_replay_buffer.npz...
# Buffer with 467130 experiences saved.

# %% [markdown]
# ## Phase 2 - Environment Info

# %%
# === Phase 2: Environment Design (Used in Eval/Interactive) ===
print("\n--- Phase 2: Environment Design ---")
print("Note: The environment class (RetailMarkdownEnv) will be instantiated")
print("      within the Evaluation and Interactive Play phases as needed.")
# Define state/action dimensions based on environment/data spec
# These should match how the data was prepared and how the env is defined
STATE_DIM = model_training.STATE_DIM # Get from module where it's defined
ACTION_DIM = model_training.ACTION_DIM # Get from module where it's defined
print(f"State Dimension: {STATE_DIM}, Action Dimension: {ACTION_DIM}")
# Out:
# --- Phase 2: Environment Design ---
# Note: The environment class (RetailMarkdownEnv) will be instantiated
#       within the Evaluation and Interactive Play phases as needed.
# State Dimension: 4, Action Dimension: 4

# %% [markdown]
# ## Phase 3 - Model Training (Offline CQL)

# %%
# === Phase 3: Model Training (Offline CQL) ===
if RUN_OFFLINE_TRAINING:
    print("\n--- Running Phase 3: Model Training (Offline CQL) ---")
    if offline_buffer is None:
         print("Error: Offline buffer not available for training. Make sure Cell 2 ran successfully or RUN_DATA_PREPARATION=False and buffer file exists.")
         raise Exception("Offline buffer is None.")

    # Initialize Agent
    print("Initializing RL Agent...")
    agent = model_training.RLAgent(
        state_size=STATE_DIM,
        action_size=ACTION_DIM,
        offline_buffer=offline_buffer, # Pass the loaded/generated offline buffer
        seed=SEED
    )

    # --- Offline Pretraining (Saves the final model) ---
    print(f"Starting Offline Pretraining (CQL) for {OFFLINE_EPOCHS} epochs...")
    try:
        agent.train_offline_cql(
            epochs=OFFLINE_EPOCHS,
            batch_size=BATCH_SIZE,
            model_save_path=FINAL_MODEL_FILE # Save directly to final path
        )
        print(f"Offline training complete. Model saved to {FINAL_MODEL_FILE}")
        # Clear buffer from memory if large and not needed anymore (agent keeps a reference internally for training)
        # del offline_buffer
        # import gc
        # gc.collect()
        # print("Offline buffer cleared from main scope memory.")
    except Exception as e:
        print(f"Error during Offline Training: {e}")
        raise
else:
    print("\n--- Skipping Phase 3: Model Training ---")
    if RUN_EVALUATION or RUN_INTERACTIVE_PLAY:
        print(f"Note: Evaluation/Interactive Play will attempt to load the model from {FINAL_MODEL_FILE}")
# Out:
# --- Running Phase 3: Model Training (Offline CQL) ---
# Initializing RL Agent...
# Agent initialized with 467130 offline experiences.
# Starting Offline Pretraining (CQL) for 5000 epochs...
# Starting CQL Offline Training for 5000 epochs (3649 batches per epoch)...
# CQL Alpha: 5.0, Target Update Freq: 100, Batch Size: 128
# Epoch 100/5000	Avg Loss: 23478933.9364	Q1 Loss: 23470369.3138	CQL Loss: 1712.9218
# Epoch 200/5000	Avg Loss: 18783386.8868	Q1 Loss: 18779161.0951	CQL Loss: 845.1608
# Epoch 300/5000	Avg Loss: 20703394.5185	Q1 Loss: 20699682.8700	CQL Loss: 742.3301
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 20
#      18 print(f"Starting Offline Pretraining (CQL) for {OFFLINE_EPOCHS} epochs...")
#      19 try:
# ---> 20     agent.train_offline_cql(
#      21         epochs=OFFLINE_EPOCHS,
#      22         batch_size=BATCH_SIZE,
#      23         model_save_path=FINAL_MODEL_FILE # Save directly to final path
#      24     )
#      25     print(f"Offline training complete. Model saved to {FINAL_MODEL_FILE}")
#      26     # Clear buffer from memory if large and not needed anymore (agent keeps a reference internally for training)
#      27     # del offline_buffer
#      28     # import gc
#      29     # gc.collect()
#      30     # print("Offline buffer cleared from main scope memory.")
#
# File c:\Users\gpnc_\OneDrive\Documentos\GitHub\Retail_Mardown_Game\Reinforcemente_Learning\model_training.py:201, in RLAgent.train_offline_cql(self, epochs, batch_size, model_save_path, cql_alpha, target_update_freq)
#     199 # Optimize the model
#     200 self.optimizer.zero_grad()
# --> 201 loss.backward()
#     202 self.optimizer.step()
#     204 epoch_loss += loss.item()
#
# File c:\Users\gpnc_\anaconda4\envs\transformers_env\lib\site-packages\torch\_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File c:\Users\gpnc_\anaconda4\envs\transformers_env\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\gpnc_\anaconda4\envs\transformers_env\lib\site-packages\torch\autograd\graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Phase 4 - Policy Evaluation

# %%
# === Phase 4: Policy Evaluation (Using Simulation Environment) ===
if RUN_EVALUATION:
    print("\n--- Running Phase 4: Policy Evaluation (Simulated) ---")
    try:
        # Create environment for evaluation
        print(f"Creating evaluation environment for Lift Tier: {TARGET_LIFT_TIER}")
        env_eval = environment.RetailMarkdownEnv(lift_tier=TARGET_LIFT_TIER) # Use different seed for eval env
        env_eval.seed(SEED + 1) # Set seed using the .seed() method

        # Load the final model (trained offline)
        print(f"Loading model for evaluation from: {FINAL_MODEL_FILE}")
        # Need to pass state/action dim to load_trained_model if the model class requires them
        model_to_eval = evaluation.load_trained_model(FINAL_MODEL_FILE, STATE_DIM, ACTION_DIM)

        rl_agent_results = None # Initialize
        if model_to_eval:
            print(f"Evaluating RL Agent Policy over {EVALUATION_EPISODES} episodes...")
            rl_agent_results = evaluation.evaluate_policy(
                env=env_eval,
                model=model_to_eval,
                n_episodes=EVALUATION_EPISODES,
                state_dim=STATE_DIM, # Pass state_dim if needed by evaluate_policy
                action_dim=ACTION_DIM # Pass action_dim if needed
            )
            print("RL Agent evaluation complete.")
        else:
            print(f"Skipping RL agent evaluation as model could not be loaded from {FINAL_MODEL_FILE}.")


        # Run benchmarks
        print("Running Benchmark Policies...")
        benchmark_policies_map = {
            "Linear Markdown": evaluation.linear_markdown_policy,
            "Rule-Based": evaluation.rule_based_policy,
            "Random Valid Actions": evaluation.random_policy
        }
        benchmark_results_list = []
        for i, (name, policy_func) in enumerate(benchmark_policies_map.items()):
            print(f"  Running Benchmark: {name}...")
            # Re-seed or reset env for each benchmark if desired for fairness
            # The initial seed for env_eval was SEED + 1.
            # For benchmarks, we use SEED + 1 + (i+1) to ensure different sequences if desired.
            # Or, more simply, SEED + 2 + i
            env_eval.seed(SEED + 2 + i) # Example re-seed, ensuring it's different from initial and other benchmarks
            results = evaluation.run_benchmark(
                env=env_eval,
                policy_func=policy_func,
                policy_name=name,
                n_episodes=EVALUATION_EPISODES
            )
            benchmark_results_list.append(results)
        print("Benchmark policies evaluation complete.")

        # Analyze and compare
        print("Analyzing and plotting results...")
        if rl_agent_results:
            evaluation.analyze_results(rl_agent_results, benchmark_results_list)
            plt.show() # Ensure plots are displayed in the notebook
        else:
             print("\nSkipping final comparison plots as RL agent results are unavailable.")

        env_eval.close()
        print("Evaluation environment closed.")

    except Exception as e:
        print(f"Error during Evaluation: {e}")
        raise
else:
    print("\n--- Skipping Phase 4: Policy Evaluation ---")
# Out:
# --- Running Phase 4: Policy Evaluation (Simulated) ---
# Creating evaluation environment for Lift Tier: 1
# Error during Evaluation: 'RetailMarkdownEnv' object has no attribute 'seed'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 8
#       6 print(f"Creating evaluation environment for Lift Tier: {TARGET_LIFT_TIER}")
#       7 env_eval = environment.RetailMarkdownEnv(lift_tier=TARGET_LIFT_TIER) # Use different seed for eval env
# ----> 8 env_eval.seed(SEED + 1) # Set seed using the .seed() method
#      10 # Load the final model (trained offline)
#      11 print(f"Loading model for evaluation from: {FINAL_MODEL_FILE}")
#
# AttributeError: 'RetailMarkdownEnv' object has no attribute 'seed'

# %%
# === Phase 4: Policy Evaluation (Using Simulation Environment) ===
import matplotlib.pyplot as plt

if RUN_EVALUATION:
    print("\n--- Running Phase 4: Policy Evaluation (Simulated) ---")
    try:
        # Create environment for evaluation
        print(f"Creating evaluation environment for Lift Tier: {TARGET_LIFT_TIER}")
        env_eval = environment.RetailMarkdownEnv(lift_tier=TARGET_LIFT_TIER)

        # Seed via reset() (Gym/Gymnasium API) and seed the spaces
        obs = env_eval.reset(seed=SEED + 1)
        try:
            env_eval.action_space.seed(SEED + 1)
            env_eval.observation_space.seed(SEED + 1)
        except AttributeError:
            # if your env doesn't expose spaces, you can also
            # fall back to numpy/random seeding globally:
            import numpy as np, random
            np.random.seed(SEED + 1)
            random.seed(SEED + 1)

        # Load the final model (trained offline)
        print(f"Loading model for evaluation from: {FINAL_MODEL_FILE}")
        model_to_eval = evaluation.load_trained_model(
            FINAL_MODEL_FILE
        )

        rl_agent_results = None
        if model_to_eval:
            print(f"Evaluating RL Agent Policy over {EVALUATION_EPISODES} episodes...")
            rl_agent_results = evaluation.evaluate_policy(
                env=env_eval,
                model=model_to_eval,
                n_episodes=EVALUATION_EPISODES
            )
            print("RL Agent evaluation complete.")
        else:
            print(f"Skipping RL agent evaluation as model could not be loaded from {FINAL_MODEL_FILE}.")

        # Run benchmarks
        print("Running Benchmark Policies...")
        benchmark_policies_map = {
            "Linear Markdown":       evaluation.linear_markdown_policy,
            "Rule-Based":            evaluation.rule_based_policy,
            "Random Valid Actions":  evaluation.random_policy
        }
        benchmark_results_list = []
        for i, (name, policy_func) in enumerate(benchmark_policies_map.items()):
            print(f"  Running Benchmark: {name}...")
            # re-seed via reset()
            obs = env_eval.reset(seed=SEED + 2 + i)
            try:
                env_eval.action_space.seed(SEED + 2 + i)
                env_eval.observation_space.seed(SEED + 2 + i)
            except AttributeError:
                pass

            results = evaluation.run_benchmark(
                env=env_eval,
                policy_func=policy_func,
                policy_name=name,
                n_episodes=EVALUATION_EPISODES
            )
            benchmark_results_list.append(results)
        print("Benchmark policies evaluation complete.")

        # Analyze and compare
        print("Analyzing and plotting results...")
        if rl_agent_results:
            evaluation.analyze_results(rl_agent_results, benchmark_results_list)
            plt.show()
        else:
            print("\nSkipping final comparison plots as RL agent results are unavailable.")

        env_eval.close()
        print("Evaluation environment closed.")

    except Exception as e:
        print(f"Error during Evaluation: {e}")
        raise

else:
    print("\n--- Skipping Phase 4: Policy Evaluation ---")
# Out:
# --- Running Phase 4: Policy Evaluation (Simulated) ---
# Creating evaluation environment for Lift Tier: 1
# Loading model for evaluation from: offline_trained_model.pth
# Successfully loaded model from offline_trained_model.pth
# Evaluating RL Agent Policy over 1000 episodes...
# --- Evaluating RL Policy (1000 episodes) ---
# Evaluated episode 1000/1000
# RL Policy Evaluation finished.
# RL Agent evaluation complete.
# Running Benchmark Policies...
#   Running Benchmark: Linear Markdown...
# --- Evaluating Benchmark: Linear Markdown (1000 episodes) ---
# Evaluated episode 1000/1000
# Linear Markdown Evaluation finished.
#   Running Benchmark: Rule-Based...
# --- Evaluating Benchmark: Rule-Based (1000 episodes) ---
# Evaluated episode 1000/1000
# Rule-Based Evaluation finished.
#   Running Benchmark: Random Valid Actions...
# --- Evaluating Benchmark: Random Valid Actions (1000 episodes) ---
# Evaluated episode 1000/1000
# Random Valid Actions Evaluation finished.
# Benchmark policies evaluation complete.
# Analyzing and plotting results...
#
# --- Evaluation Analysis ---
# Policy: RL Agent (Fine-tuned)
#   Avg Reward: 71152.67 +/- 4194.57
#   Median Reward: 71438.00
#   Avg Final Inv: 114.45
#   Median Final Inv: 108.50
# Policy: Linear Markdown
#   Avg Reward: 81798.44 +/- 5467.68
#   Median Reward: 81816.00
#   Avg Final Inv: 356.42
#   Median Final Inv: 355.00
# Policy: Rule-Based
#   Avg Reward: 80656.98 +/- 5550.02
#   Median Reward: 80582.00
#   Avg Final Inv: 347.17
#   Median Final Inv: 342.00
# Policy: Random Valid Actions
#   Avg Reward: 70768.94 +/- 4327.66
#   Median Reward: 71540.00
#   Avg Final Inv: 95.31
#   Median Final Inv: 84.00
#
# Summary Table:
#                Policy  Mean Reward  Median Reward  Std Reward  Mean Final Inv  Median Final Inv
# RL Agent (Fine-tuned)     71152.67       71438.00     4194.57          114.45            108.50
#       Linear Markdown     81798.44       81816.00     5467.68          356.42            355.00
#            Rule-Based     80656.98       80582.00     5550.02          347.17            342.00
#  Random Valid Actions     70768.94       71540.00     4327.66           95.31             84.00
#
# Saved reward distribution plot to evaluation_reward_distribution.png
# Saved final inventory distribution plot to evaluation_final_inventory_distribution.png
# Evaluation environment closed.

# %% [markdown]
# ## Phase 5 - Interactive Online Play Placeholder

# %%
# Example of how to call the interactive game playing script from Python.

import subprocess
import os
import sys # Import sys to use sys.executable

def run_game_player(num_games_to_play, lift_tier=1): # Added lift_tier argument
    script_name = "prueba.py"
    # Assume the script 'prueba.py' is in the same directory as this notebook ('main.ipynb').
    # In a notebook context, os.getcwd() usually reflects the directory where the
    # Jupyter server was started, which we assume is the 'Reinforcemente_Learning' directory
    # or the project root containing it.
    current_dir = os.getcwd()
    script_path = os.path.join(current_dir, script_name)
    script_dir = current_dir # Initial assumption: script is directly in current_dir

    # Check if the script exists at the primary assumed path (e.g., CWD is Reinforcemente_Learning)
    if not os.path.exists(script_path):
        print(f"Warning: Script '{script_name}' not found directly in the current directory: {current_dir}")
        # Try finding it assuming CWD is the project root (one level above Reinforcemente_Learning)
        alt_script_path = os.path.join(current_dir, "Reinforcemente_Learning", script_name)
        if os.path.exists(alt_script_path):
            script_path = alt_script_path
            script_dir = os.path.dirname(script_path) # Update script directory
            print(f"Found script at alternative path: {script_path}")
        else:
            print(f"Error: Script '{script_name}' not found at primary path ({script_path}) or alternative path ({alt_script_path}).")
            print(f"Please ensure '{script_name}' is correctly located relative to the notebook execution directory ({current_dir}).")
            return

    # Construct the expected path for the results CSV, relative to the script's directory
    results_csv_path = os.path.join(script_dir, "rl_game_outcomes.csv")

    try:
        print(f"Running {script_name} from {script_dir} with {num_games_to_play} games and lift tier {lift_tier}...")
        # Use sys.executable to ensure the same Python interpreter is used
        # Use the determined script_path
        command = [
            sys.executable,
            script_path,
            "--num_games", str(num_games_to_play),
            "--lift_tier", str(lift_tier) # Add lift_tier to the command
        ]

        # Execute the script with its own directory as the current working directory (cwd)
        # This helps the script find relative paths (like model files) correctly.
        process = subprocess.Popen(
            command,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True, # Decode stdout/stderr as text
            cwd=script_dir # Set working directory for the subprocess
        )

        # Real-time output streaming (optional but helpful for monitoring)
        print("--- Game Player Output Start ---")
        while True:
            output = process.stdout.readline()
            if output == '' and process.poll() is not None: # Process finished
                break
            if output:
                print(output.strip()) # Print live output from the script

        # Capture any remaining stderr output after the process finishes
        stderr_output = process.stderr.read()
        if stderr_output:
            print("--- Game Player Error Output ---")
            print(stderr_output.strip())
            print("------------------------------")

        process.wait() # Wait for the process to complete fully
        print(f"--- Game Player Output End ---")
        print(f"{script_name} finished with exit code {process.returncode}")

        # Check if the results file was created in the expected location
        if os.path.exists(results_csv_path):
             print(f"Game results should be saved to: {results_csv_path}")
        else:
             print(f"Warning: Game results CSV not found at the expected path: {results_csv_path}")


    except FileNotFoundError:
        # This error usually means sys.executable or script_path is wrong
        print(f"Error: Python executable '{sys.executable}' or script '{script_path}' not found.")
        print("Ensure Python is correctly installed and in PATH, and the script path is valid.")
    except Exception as e:
        print(f"An error occurred while trying to run the script '{script_name}': {e}")

# This block allows running the function directly if this cell is executed.
# Note: In a notebook, __name__ is usually "__main__" for the executed cell.
if __name__ == "__main__":
    print("Executing game player function from notebook cell...")
    # Example: Run 1 game with lift tier 1
    run_game_player(num_games_to_play=100, lift_tier=3)
# Out:
# Executing game player function from notebook cell...
# Running prueba.py from c:\Users\gpnc_\OneDrive\Documentos\GitHub\Retail_Mardown_Game\Reinforcemente_Learning with 100 games and lift tier 3...
# --- Game Player Output Start ---
# Using device: cpu
# Using device: cpu
# Starting script: Interactive RL Agent Game Play
#
# --- Running Interactive Online Play with RL Agent for 100 game(s) ---
# Loading model for inference from: c:\Users\gpnc_\OneDrive\Documentos\GitHub\Retail_Mardown_Game\Reinforcemente_Learning\offline_trained_model.pth
# Inference model loaded successfully from c:\Users\gpnc_\OneDrive\Documentos\GitHub\Retail_Mardown_Game\Reinforcemente_Learning\offline_trained_model.pth
# Inference module loaded successfully.
# Setting up browser...
# Navigating to https://www.randhawa.us/games/retailer/nyu.html...
# Browser setup complete.
#
# --- Playing Game 1/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1898
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1790
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76392, Optimal Revenue=110826
# Game 1 finished. Agent Revenue: 76392, Optimal Revenue: 110826
#
# --- Playing Game 2/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1872
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75072, Optimal Revenue=115800
# Game 2 finished. Agent Revenue: 75072, Optimal Revenue: 115800
#
# --- Playing Game 3/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1961
# Predicting action for week 2
# Clicking Action: 0 (Button ID: maintainButton)
# Getting game state...
# State: Week=2, Price=60.0, Inv=1924
# Predicting action for week 3
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=3, Price=54.0, Inv=1836
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=375
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=61908, Optimal Revenue=65484
# Game 3 finished. Agent Revenue: 61908, Optimal Revenue: 65484
#
# --- Playing Game 4/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1915
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1853
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75156, Optimal Revenue=97392
# Game 4 finished. Agent Revenue: 75156, Optimal Revenue: 97392
#
# --- Playing Game 5/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1943
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1900
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1820
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=158
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=69414, Optimal Revenue=71208
# Game 5 finished. Agent Revenue: 69414, Optimal Revenue: 71208
#
# --- Playing Game 6/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1920
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1856
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75072, Optimal Revenue=93036
# Game 6 finished. Agent Revenue: 75072, Optimal Revenue: 93036
#
# --- Playing Game 7/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1886
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1752
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1542
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79668, Optimal Revenue=115194
# Game 7 finished. Agent Revenue: 79668, Optimal Revenue: 115194
#
# --- Playing Game 8/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1874
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75024, Optimal Revenue=119082
# Game 8 finished. Agent Revenue: 75024, Optimal Revenue: 119082
#
# --- Playing Game 9/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1901
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1775
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1637
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=78300, Optimal Revenue=104520
# Game 9 finished. Agent Revenue: 78300, Optimal Revenue: 104520
#
# --- Playing Game 10/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1911
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1826
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75666, Optimal Revenue=100254
# Game 10 finished. Agent Revenue: 75666, Optimal Revenue: 100254
#
# --- Playing Game 11/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1914
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1812
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75900, Optimal Revenue=92328
# Game 11 finished. Agent Revenue: 75900, Optimal Revenue: 92328
#
# --- Playing Game 12/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1903
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1776
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76614, Optimal Revenue=106146
# Game 12 finished. Agent Revenue: 76614, Optimal Revenue: 106146
#
# --- Playing Game 13/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1961
# Predicting action for week 2
# Clicking Action: 0 (Button ID: maintainButton)
# Getting game state...
# State: Week=2, Price=60.0, Inv=1908
# Predicting action for week 3
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=3, Price=54.0, Inv=1880
# Predicting action for week 4
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=4, Price=48.0, Inv=1837
# Predicting action for week 5
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=704
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=49884, Optimal Revenue=53136
# Game 13 finished. Agent Revenue: 49884, Optimal Revenue: 53136
#
# --- Playing Game 14/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1890
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1778
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76656, Optimal Revenue=112284
# Game 14 finished. Agent Revenue: 76656, Optimal Revenue: 112284
#
# --- Playing Game 15/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1943
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1829
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75420, Optimal Revenue=77436
# Game 15 finished. Agent Revenue: 75420, Optimal Revenue: 77436
#
# --- Playing Game 16/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1871
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75096, Optimal Revenue=114396
# Game 16 finished. Agent Revenue: 75096, Optimal Revenue: 114396
#
# --- Playing Game 17/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1907
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1790
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76338, Optimal Revenue=103794
# Game 17 finished. Agent Revenue: 76338, Optimal Revenue: 103794
#
# --- Playing Game 18/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1882
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1714
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1529
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=80076, Optimal Revenue=109482
# Game 18 finished. Agent Revenue: 80076, Optimal Revenue: 109482
#
# --- Playing Game 19/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1884
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1735
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1570
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79446, Optimal Revenue=108696
# Game 19 finished. Agent Revenue: 79446, Optimal Revenue: 108696
#
# --- Playing Game 20/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1956
# Predicting action for week 2
# Clicking Action: 0 (Button ID: maintainButton)
# Getting game state...
# State: Week=2, Price=60.0, Inv=1926
# Predicting action for week 3
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=3, Price=54.0, Inv=1885
# Predicting action for week 4
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=4, Price=48.0, Inv=1794
# Predicting action for week 5
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=488
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=58038, Optimal Revenue=61140
# Game 20 finished. Agent Revenue: 58038, Optimal Revenue: 61140
#
# --- Playing Game 21/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1900
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1749
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1585
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79086, Optimal Revenue=103536
# Game 21 finished. Agent Revenue: 79086, Optimal Revenue: 103536
#
# --- Playing Game 22/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1945
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1886
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1756
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=59
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=73818, Optimal Revenue=74424
# Game 22 finished. Agent Revenue: 73818, Optimal Revenue: 74424
#
# --- Playing Game 23/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1933
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1848
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75138, Optimal Revenue=88578
# Game 23 finished. Agent Revenue: 75138, Optimal Revenue: 88578
#
# --- Playing Game 24/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1902
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1772
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1589
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=78888, Optimal Revenue=106494
# Game 24 finished. Agent Revenue: 78888, Optimal Revenue: 106494
#
# --- Playing Game 25/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1875
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75000, Optimal Revenue=116958
# Game 25 finished. Agent Revenue: 75000, Optimal Revenue: 116958
#
# --- Playing Game 26/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1924
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1890
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1759
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76008, Optimal Revenue=89256
# Game 26 finished. Agent Revenue: 76008, Optimal Revenue: 89256
#
# --- Playing Game 27/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1897
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1748
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1681
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=77958, Optimal Revenue=111402
# Game 27 finished. Agent Revenue: 77958, Optimal Revenue: 111402
#
# --- Playing Game 28/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1863
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75288, Optimal Revenue=120000
# Game 28 finished. Agent Revenue: 75288, Optimal Revenue: 120000
#
# --- Playing Game 29/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1929
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1831
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75468, Optimal Revenue=87780
# Game 29 finished. Agent Revenue: 75468, Optimal Revenue: 87780
#
# --- Playing Game 30/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1880
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1658
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1383
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=82176, Optimal Revenue=111990
# Game 30 finished. Agent Revenue: 82176, Optimal Revenue: 111990
#
# --- Playing Game 31/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1931
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1809
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75852, Optimal Revenue=94668
# Game 31 finished. Agent Revenue: 75852, Optimal Revenue: 94668
#
# --- Playing Game 32/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1829
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1678
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1374
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=82470, Optimal Revenue=120000
# Game 32 finished. Agent Revenue: 82470, Optimal Revenue: 120000
#
# --- Playing Game 33/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1912
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1819
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75786, Optimal Revenue=106104
# Game 33 finished. Agent Revenue: 75786, Optimal Revenue: 106104
#
# --- Playing Game 34/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1901
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1744
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1615
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=78750, Optimal Revenue=109314
# Game 34 finished. Agent Revenue: 78750, Optimal Revenue: 109314
#
# --- Playing Game 35/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1989
# Predicting action for week 2
# Clicking Action: 0 (Button ID: maintainButton)
# Getting game state...
# State: Week=2, Price=60.0, Inv=1983
# Predicting action for week 3
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=3, Price=54.0, Inv=1965
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=1555
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=16752, Optimal Revenue=17436
# Game 35 finished. Agent Revenue: 16752, Optimal Revenue: 17436
#
# --- Playing Game 36/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1916
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1785
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76374, Optimal Revenue=92772
# Game 36 finished. Agent Revenue: 76374, Optimal Revenue: 92772
#
# --- Playing Game 37/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1884
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1749
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1560
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79482, Optimal Revenue=107256
# Game 37 finished. Agent Revenue: 79482, Optimal Revenue: 107256
#
# --- Playing Game 38/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1928
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1851
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75114, Optimal Revenue=86688
# Game 38 finished. Agent Revenue: 75114, Optimal Revenue: 86688
#
# --- Playing Game 39/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1909
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1801
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76128, Optimal Revenue=100764
# Game 39 finished. Agent Revenue: 76128, Optimal Revenue: 100764
#
# --- Playing Game 40/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1892
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1757
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1541
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79614, Optimal Revenue=115338
# Game 40 finished. Agent Revenue: 79614, Optimal Revenue: 115338
#
# --- Playing Game 41/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1903
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1731
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1562
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79452, Optimal Revenue=108582
# Game 41 finished. Agent Revenue: 79452, Optimal Revenue: 108582
#
# --- Playing Game 42/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1946
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1858
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=181
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=68364, Optimal Revenue=70452
# Game 42 finished. Agent Revenue: 68364, Optimal Revenue: 70452
#
# --- Playing Game 43/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1953
# Predicting action for week 2
# Clicking Action: 0 (Button ID: maintainButton)
# Getting game state...
# State: Week=2, Price=60.0, Inv=1898
# Predicting action for week 3
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=3, Price=54.0, Inv=1820
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=309
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=64728, Optimal Revenue=68772
# Game 43 finished. Agent Revenue: 64728, Optimal Revenue: 68772
#
# --- Playing Game 44/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1915
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1792
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76254, Optimal Revenue=97020
# Game 44 finished. Agent Revenue: 76254, Optimal Revenue: 97020
#
# --- Playing Game 45/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1965
# Predicting action for week 2
# Clicking Action: 0 (Button ID: maintainButton)
# Getting game state...
# State: Week=2, Price=60.0, Inv=1922
# Predicting action for week 3
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=3, Price=54.0, Inv=1882
# Predicting action for week 4
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=4, Price=48.0, Inv=1837
# Predicting action for week 5
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=695
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=50112, Optimal Revenue=53292
# Game 45 finished. Agent Revenue: 50112, Optimal Revenue: 53292
#
# --- Playing Game 46/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1911
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1748
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1633
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=78450, Optimal Revenue=100494
# Game 46 finished. Agent Revenue: 78450, Optimal Revenue: 100494
#
# --- Playing Game 47/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1925
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1852
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75114, Optimal Revenue=94596
# Game 47 finished. Agent Revenue: 75114, Optimal Revenue: 94596
#
# --- Playing Game 48/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1898
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1782
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76536, Optimal Revenue=106038
# Game 48 finished. Agent Revenue: 76536, Optimal Revenue: 106038
#
# --- Playing Game 49/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1931
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1842
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75258, Optimal Revenue=89964
# Game 49 finished. Agent Revenue: 75258, Optimal Revenue: 89964
#
# --- Playing Game 50/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1911
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1765
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1633
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=78348, Optimal Revenue=107580
# Game 50 finished. Agent Revenue: 78348, Optimal Revenue: 107580
#
# --- Playing Game 51/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1880
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1709
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1557
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79782, Optimal Revenue=112392
# Game 51 finished. Agent Revenue: 79782, Optimal Revenue: 112392
#
# --- Playing Game 52/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1913
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1797
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76176, Optimal Revenue=102858
# Game 52 finished. Agent Revenue: 76176, Optimal Revenue: 102858
#
# --- Playing Game 53/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1875
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75000, Optimal Revenue=120000
# Game 53 finished. Agent Revenue: 75000, Optimal Revenue: 120000
#
# --- Playing Game 54/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1933
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1870
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74742, Optimal Revenue=90672
# Game 54 finished. Agent Revenue: 74742, Optimal Revenue: 90672
#
# --- Playing Game 55/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1930
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1803
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75966, Optimal Revenue=87444
# Game 55 finished. Agent Revenue: 75966, Optimal Revenue: 87444
#
# --- Playing Game 56/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1937
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1840
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75258, Optimal Revenue=84084
# Game 56 finished. Agent Revenue: 75258, Optimal Revenue: 84084
#
# --- Playing Game 57/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1965
# Predicting action for week 2
# Clicking Action: 0 (Button ID: maintainButton)
# Getting game state...
# State: Week=2, Price=60.0, Inv=1924
# Predicting action for week 3
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=3, Price=54.0, Inv=1876
# Predicting action for week 4
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=4, Price=48.0, Inv=1835
# Predicting action for week 5
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=725
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=49080, Optimal Revenue=52284
# Game 57 finished. Agent Revenue: 49080, Optimal Revenue: 52284
#
# --- Playing Game 58/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1884
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1761
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1555
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79470, Optimal Revenue=109266
# Game 58 finished. Agent Revenue: 79470, Optimal Revenue: 109266
#
# --- Playing Game 59/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1928
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1776
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76464, Optimal Revenue=93816
# Game 59 finished. Agent Revenue: 76464, Optimal Revenue: 93816
#
# --- Playing Game 60/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1882
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1771
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1637
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=78438, Optimal Revenue=115338
# Game 60 finished. Agent Revenue: 78438, Optimal Revenue: 115338
#
# --- Playing Game 61/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1881
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1686
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1508
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=80502, Optimal Revenue=115338
# Game 61 finished. Agent Revenue: 80502, Optimal Revenue: 115338
#
# --- Playing Game 62/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1946
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1870
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74664, Optimal Revenue=74664
# Game 62 finished. Agent Revenue: 74664, Optimal Revenue: 74664
#
# --- Playing Game 63/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1870
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75120, Optimal Revenue=120000
# Game 63 finished. Agent Revenue: 75120, Optimal Revenue: 120000
#
# --- Playing Game 64/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1946
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1908
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1801
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=290
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=64824, Optimal Revenue=66708
# Game 64 finished. Agent Revenue: 64824, Optimal Revenue: 66708
#
# --- Playing Game 65/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1866
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75216, Optimal Revenue=118428
# Game 65 finished. Agent Revenue: 75216, Optimal Revenue: 118428
#
# --- Playing Game 66/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1893
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1830
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75702, Optimal Revenue=103704
# Game 66 finished. Agent Revenue: 75702, Optimal Revenue: 103704
#
# --- Playing Game 67/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1898
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1788
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76428, Optimal Revenue=112596
# Game 67 finished. Agent Revenue: 76428, Optimal Revenue: 112596
#
# --- Playing Game 68/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1937
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1834
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75366, Optimal Revenue=87564
# Game 68 finished. Agent Revenue: 75366, Optimal Revenue: 87564
#
# --- Playing Game 69/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1933
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1831
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75444, Optimal Revenue=84516
# Game 69 finished. Agent Revenue: 75444, Optimal Revenue: 84516
#
# --- Playing Game 70/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1888
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1675
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1501
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=80610, Optimal Revenue=111168
# Game 70 finished. Agent Revenue: 80610, Optimal Revenue: 111168
#
# --- Playing Game 71/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1905
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1831
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75612, Optimal Revenue=103842
# Game 71 finished. Agent Revenue: 75612, Optimal Revenue: 103842
#
# --- Playing Game 72/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1936
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1861
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74886, Optimal Revenue=84198
# Game 72 finished. Agent Revenue: 74886, Optimal Revenue: 84198
#
# --- Playing Game 73/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1934
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1862
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74880, Optimal Revenue=91476
# Game 73 finished. Agent Revenue: 74880, Optimal Revenue: 91476
#
# --- Playing Game 74/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1974
# Predicting action for week 2
# Clicking Action: 0 (Button ID: maintainButton)
# Getting game state...
# State: Week=2, Price=60.0, Inv=1956
# Predicting action for week 3
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=3, Price=54.0, Inv=1938
# Predicting action for week 4
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=4, Price=48.0, Inv=1902
# Predicting action for week 5
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=1237
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=29280, Optimal Revenue=30756
# Game 74 finished. Agent Revenue: 29280, Optimal Revenue: 30756
#
# --- Playing Game 75/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1935
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1845
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75180, Optimal Revenue=88284
# Game 75 finished. Agent Revenue: 75180, Optimal Revenue: 88284
#
# --- Playing Game 76/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1905
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1804
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76098, Optimal Revenue=103338
# Game 76 finished. Agent Revenue: 76098, Optimal Revenue: 103338
#
# --- Playing Game 77/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1912
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1856
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75120, Optimal Revenue=101472
# Game 77 finished. Agent Revenue: 75120, Optimal Revenue: 101472
#
# --- Playing Game 78/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1901
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1721
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1588
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79212, Optimal Revenue=109266
# Game 78 finished. Agent Revenue: 79212, Optimal Revenue: 109266
#
# --- Playing Game 79/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1914
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1805
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=76026, Optimal Revenue=98496
# Game 79 finished. Agent Revenue: 76026, Optimal Revenue: 98496
#
# --- Playing Game 80/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1930
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1868
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74796, Optimal Revenue=89004
# Game 80 finished. Agent Revenue: 74796, Optimal Revenue: 89004
#
# --- Playing Game 81/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1926
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1804
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75972, Optimal Revenue=91176
# Game 81 finished. Agent Revenue: 75972, Optimal Revenue: 91176
#
# --- Playing Game 82/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1946
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1874
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74592, Optimal Revenue=80316
# Game 82 finished. Agent Revenue: 74592, Optimal Revenue: 80316
#
# --- Playing Game 83/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1915
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1844
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75318, Optimal Revenue=102390
# Game 83 finished. Agent Revenue: 75318, Optimal Revenue: 102390
#
# --- Playing Game 84/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1905
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1763
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1631
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=78420, Optimal Revenue=106626
# Game 84 finished. Agent Revenue: 78420, Optimal Revenue: 106626
#
# --- Playing Game 85/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1900
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1770
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1558
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79284, Optimal Revenue=108648
# Game 85 finished. Agent Revenue: 79284, Optimal Revenue: 108648
#
# --- Playing Game 86/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1938
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1869
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74730, Optimal Revenue=88962
# Game 86 finished. Agent Revenue: 74730, Optimal Revenue: 88962
#
# --- Playing Game 87/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1884
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1700
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1481
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=80724, Optimal Revenue=114138
# Game 87 finished. Agent Revenue: 80724, Optimal Revenue: 114138
#
# --- Playing Game 88/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1911
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1815
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75864, Optimal Revenue=97956
# Game 88 finished. Agent Revenue: 75864, Optimal Revenue: 97956
#
# --- Playing Game 89/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1924
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1873
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74742, Optimal Revenue=90156
# Game 89 finished. Agent Revenue: 74742, Optimal Revenue: 90156
#
# --- Playing Game 90/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1875
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75000, Optimal Revenue=120000
# Game 90 finished. Agent Revenue: 75000, Optimal Revenue: 120000
#
# --- Playing Game 91/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1940
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1903
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1781
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75570, Optimal Revenue=83586
# Game 91 finished. Agent Revenue: 75570, Optimal Revenue: 83586
#
# --- Playing Game 92/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1905
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1752
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1601
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=78846, Optimal Revenue=105618
# Game 92 finished. Agent Revenue: 78846, Optimal Revenue: 105618
#
# --- Playing Game 93/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1915
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1843
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75336, Optimal Revenue=97908
# Game 93 finished. Agent Revenue: 75336, Optimal Revenue: 97908
#
# --- Playing Game 94/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1897
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1736
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1635
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=78582, Optimal Revenue=103560
# Game 94 finished. Agent Revenue: 78582, Optimal Revenue: 103560
#
# --- Playing Game 95/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1925
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1871
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74772, Optimal Revenue=96900
# Game 95 finished. Agent Revenue: 74772, Optimal Revenue: 96900
#
# --- Playing Game 96/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1881
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1734
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1487
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=80466, Optimal Revenue=113598
# Game 96 finished. Agent Revenue: 80466, Optimal Revenue: 113598
#
# --- Playing Game 97/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1945
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1867
# Predicting action for week 3
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=74724, Optimal Revenue=82092
# Game 97 finished. Agent Revenue: 74724, Optimal Revenue: 82092
#
# --- Playing Game 98/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1901
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1757
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1582
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79068, Optimal Revenue=108114
# Game 98 finished. Agent Revenue: 79068, Optimal Revenue: 108114
#
# --- Playing Game 99/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1900
# Predicting action for week 2
# Clicking Action: 1 (Button ID: tenButton)
# Getting game state...
# State: Week=2, Price=54.0, Inv=1733
# Predicting action for week 3
# Clicking Action: 2 (Button ID: twentyButton)
# Getting game state...
# State: Week=3, Price=48.0, Inv=1534
# Predicting action for week 4
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=79794, Optimal Revenue=106470
# Game 99 finished. Agent Revenue: 79794, Optimal Revenue: 106470
#
# --- Playing Game 100/100 (Lift Tier: 3) ---
# Starting new game...
# Game started.
# Getting game state...
# State: Week=1, Price=60.0, Inv=1860
# Predicting action for week 2
# Clicking Action: 3 (Button ID: fortyButton)
# Getting game state...
# State: Week=15, Price=36.0, Inv=0
# Reached end of decision weeks.
# Getting final results...
# Results: Agent Revenue=75360, Optimal Revenue=120000
# Game 100 finished. Agent Revenue: 75360, Optimal Revenue: 120000
#
# All interactive play sessions finished.
# Closing browser...
#
# Saving game outcomes to c:\Users\gpnc_\OneDrive\Documentos\GitHub\Retail_Mardown_Game\Reinforcemente_Learning\rl_game_outcomes.csv...
# Results saved successfully to c:\Users\gpnc_\OneDrive\Documentos\GitHub\Retail_Mardown_Game\Reinforcemente_Learning\rl_game_outcomes.csv
#
# --- Script Finished ---
# --- Game Player Output End ---
# prueba.py finished with exit code 0
# Game results should be saved to: c:\Users\gpnc_\OneDrive\Documentos\GitHub\Retail_Mardown_Game\Reinforcemente_Learning\rl_game_outcomes.csv

# %% [markdown]
# ### Graph for lift_tier 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV
df = pd.read_csv("rl_game_outcomes_1.csv")

# Ensure required columns exist
if 'optimal_revenue' not in df.columns or 'agent_revenue' not in df.columns:
    print("Error: The CSV must contain 'optimal_revenue' and 'agent_revenue' columns.")
else:
    # Calculate the revenue gap
    df['revenue_gap'] = df['optimal_revenue'] - df['agent_revenue']

    # Calculate main metrics for the revenue gap
    mean_gap = np.mean(df['revenue_gap'])
    std_dev_gap = np.std(df['revenue_gap'])
    min_gap = np.min(df['revenue_gap'])
    max_gap = np.max(df['revenue_gap'])
    median_gap = np.median(df['revenue_gap'])

    print("--- Revenue Gap Statistics ---")
    print(f"Mean Gap: {mean_gap:.2f}")
    print(f"Median Gap: {median_gap:.2f}")
    print(f"Standard Deviation of Gap: {std_dev_gap:.2f}")
    print(f"Minimum Gap: {min_gap:.2f}")
    print(f"Maximum Gap: {max_gap:.2f}")
    print(f"Number of Games Analyzed: {len(df)}")

    # Create the distribution plot (histogram)
    plt.figure(figsize=(10, 6))
    plt.hist(df['revenue_gap'], bins=20, edgecolor='black', alpha=0.7)

    # Add lines for mean and median
    plt.axvline(mean_gap, linestyle='dashed', linewidth=1.5, label=f'Mean Gap: {mean_gap:.2f}')
    plt.axvline(median_gap, linestyle='dashed', linewidth=1.5, label=f'Median Gap: {median_gap:.2f}')

    # Titles and labels
    plt.title('Distribution of Revenue Gap (Optimal - Agent)')
    plt.xlabel('Revenue Gap')
    plt.ylabel('Frequency (Number of Games)')
    plt.legend()
    plt.grid(axis='y', linestyle='--', linewidth=0.5)

    # Improve layout and display
    plt.tight_layout()
    plt.show()
# Out:
# --- Revenue Gap Statistics ---
# Mean Gap: 25024.50
# Median Gap: 26931.00
# Standard Deviation of Gap: 12794.81
# Minimum Gap: 582.00
# Maximum Gap: 44976.00
# Number of Games Analyzed: 100

# %% [markdown]
# ### Graph for lift_tier 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV
df = pd.read_csv("rl_game_outcomes_2.csv")

# Ensure required columns exist
if 'optimal_revenue' not in df.columns or 'agent_revenue' not in df.columns:
    print("Error: The CSV must contain 'optimal_revenue' and 'agent_revenue' columns.")
else:
    # Calculate the revenue gap
    df['revenue_gap'] = df['optimal_revenue'] - df['agent_revenue']

    # Calculate main metrics for the revenue gap
    mean_gap = np.mean(df['revenue_gap'])
    std_dev_gap = np.std(df['revenue_gap'])
    min_gap = np.min(df['revenue_gap'])
    max_gap = np.max(df['revenue_gap'])
    median_gap = np.median(df['revenue_gap'])

    print("--- Revenue Gap Statistics ---")
    print(f"Mean Gap: {mean_gap:.2f}")
    print(f"Median Gap: {median_gap:.2f}")
    print(f"Standard Deviation of Gap: {std_dev_gap:.2f}")
    print(f"Minimum Gap: {min_gap:.2f}")
    print(f"Maximum Gap: {max_gap:.2f}")
    print(f"Number of Games Analyzed: {len(df)}")

    # Create the distribution plot (histogram)
    plt.figure(figsize=(10, 6))
    plt.hist(df['revenue_gap'], bins=20, edgecolor='black', alpha=0.7)

    # Add lines for mean and median
    plt.axvline(mean_gap, linestyle='dashed', linewidth=1.5, label=f'Mean Gap: {mean_gap:.2f}')
    plt.axvline(median_gap, linestyle='dashed', linewidth=1.5, label=f'Median Gap: {median_gap:.2f}')

    # Titles and labels
    plt.title('Distribution of Revenue Gap (Optimal - Agent)')
    plt.xlabel('Revenue Gap')
    plt.ylabel('Frequency (Number of Games)')
    plt.legend()
    plt.grid(axis='y', linestyle='--', linewidth=0.5)

    # Improve layout and display
    plt.tight_layout()
    plt.show()
# Out:
# --- Revenue Gap Statistics ---
# Mean Gap: 23287.98
# Median Gap: 23646.00
# Standard Deviation of Gap: 11205.81
# Minimum Gap: 732.00
# Maximum Gap: 44976.00
# Number of Games Analyzed: 100

# %% [markdown]
# ### Graph for lift_tier 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV
df = pd.read_csv("rl_game_outcomes_3.csv")

# Ensure required columns exist
if 'optimal_revenue' not in df.columns or 'agent_revenue' not in df.columns:
    print("Error: The CSV must contain 'optimal_revenue' and 'agent_revenue' columns.")
else:
    # Calculate the revenue gap
    df['revenue_gap'] = df['optimal_revenue'] - df['agent_revenue']

    # Calculate main metrics for the revenue gap
    mean_gap = np.mean(df['revenue_gap'])
    std_dev_gap = np.std(df['revenue_gap'])
    min_gap = np.min(df['revenue_gap'])
    max_gap = np.max(df['revenue_gap'])
    median_gap = np.median(df['revenue_gap'])

    print("--- Revenue Gap Statistics ---")
    print(f"Mean Gap: {mean_gap:.2f}")
    print(f"Median Gap: {median_gap:.2f}")
    print(f"Standard Deviation of Gap: {std_dev_gap:.2f}")
    print(f"Minimum Gap: {min_gap:.2f}")
    print(f"Maximum Gap: {max_gap:.2f}")
    print(f"Number of Games Analyzed: {len(df)}")

    # Create the distribution plot (histogram)
    plt.figure(figsize=(10, 6))
    plt.hist(df['revenue_gap'], bins=20, edgecolor='black', alpha=0.7)

    # Add lines for mean and median
    plt.axvline(mean_gap, linestyle='dashed', linewidth=1.5, label=f'Mean Gap: {mean_gap:.2f}')
    plt.axvline(median_gap, linestyle='dashed', linewidth=1.5, label=f'Median Gap: {median_gap:.2f}')

    # Titles and labels
    plt.title('Distribution of Revenue Gap (Optimal - Agent)')
    plt.xlabel('Revenue Gap')
    plt.ylabel('Frequency (Number of Games)')
    plt.legend()
    plt.grid(axis='y', linestyle='--', linewidth=0.5)

    # Improve layout and display
    plt.tight_layout()
    plt.show()
# Out:
# --- Revenue Gap Statistics ---
# Mean Gap: 22549.56
# Median Gap: 24807.00
# Standard Deviation of Gap: 12487.14
# Minimum Gap: 0.00
# Maximum Gap: 45000.00
# Number of Games Analyzed: 100
